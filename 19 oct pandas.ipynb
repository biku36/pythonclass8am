# %%
try:
    file=open('data.csv','x')
    file.close()
except:
    print("the file is already created")
# Out:
# the file is already created

# %%
import pandas as pd
df=pd.read_csv('data.csv')
df
# Out:
#    SN  Name  Age       Add       Phone
# 0   1   ram   25       ktm  9861113255
# 1   2   sma   25       bkt   956644522
# 2   3  rama   66  lalitpur  9861114255
# 3   4  dada   22  janakpur  9864446533
# 4   5   don   44       ktm   986443255
# 5   6  sita   46       bkt  9586332546

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df
# Out:
#     Name  Age       Add       Phone
# SN
# 1    ram   25       ktm  9861113255
# 2    sma   25       bkt   956644522
# 3   rama   66  lalitpur  9861114255
# 4   dada   22  janakpur  9864446533
# 5    don   44       ktm   986443255
# 6   sita   46       bkt  9586332546

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df.head(2)
# Out:
#    Name  Age  Add       Phone
# SN
# 1   ram   25  ktm  9861113255
# 2   sma   25  bkt   956644522

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df.tail(2)
# Out:
#     Name  Age  Add       Phone
# SN
# 5    don   44  ktm   986443255
# 6   sita   46  bkt  9586332546

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df.iloc[2:4]
# Out:
#     Name  Age       Add       Phone
# SN
# 3   rama   66  lalitpur  9861114255
# 4   dada   22  janakpur  9864446533

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df.iloc[2:4,0:2]
# Out:
#     Name  Age
# SN
# 3   rama   66
# 4   dada   22

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN',usecols=['SN','Name','Phone'])
df
# Out:
#     Name       Phone
# SN
# 1    ram  9861113255
# 2    sma   956644522
# 3   rama  9861114255
# 4   dada  9864446533
# 5    don   986443255
# 6   sita  9586332546

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df.loc[2:5]
# Out:
#     Name  Age       Add       Phone
# SN
# 2    sma   25       bkt   956644522
# 3   rama   66  lalitpur  9861114255
# 4   dada   22  janakpur  9864446533
# 5    don   44       ktm   986443255

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='Name')
df.loc['sma':'dada']
# Out:
#       SN  Age       Add       Phone
# Name
# sma    2   25       bkt   956644522
# rama   3   66  lalitpur  9861114255
# dada   4   22  janakpur  9864446533

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df['Add']
# Out:
# SN
# 1         ktm
# 2         bkt
# 3    lalitpur
# 4    janakpur
# 5         ktm
# 6         bkt
# Name: Add, dtype: object

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df['Add']=='ktm'
# Out:
# SN
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# Name: Add, dtype: bool

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df[df['Add']=='ktm']
# Out:
#    Name  Age  Add       Phone
# SN
# 1   ram   25  ktm  9861113255
# 5   don   44  ktm   986443255

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df['Age']>30
# Out:
# SN
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# Name: Age, dtype: bool

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
df[df['Age']>30]
# Out:
#     Name  Age       Add       Phone
# SN
# 3   rama   66  lalitpur  9861114255
# 5    don   44       ktm   986443255
# 6   sita   46       bkt  9586332546

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
data=df[df['Age']>30]
data.to_csv('new_data.csv')
data
# Out:
#     Name  Age       Add       Phone
# SN
# 3   rama   66  lalitpur  9861114255
# 5    don   44       ktm   986443255
# 6   sita   46       bkt  9586332546

# %%
df=pd.read_csv('new_data.csv')
df
# Out:
#    SN  Name  Age       Add       Phone
# 0   3  rama   66  lalitpur  9861114255
# 1   5   don   44       ktm   986443255
# 2   6  sita   46       bkt  9586332546

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='SN')
data=df[(df['Age']>30) & (df['Add']=='ktm')]
data
# Out:
#    Name  Age  Add      Phone
# SN
# 5   don   44  ktm  986443255

# %%
data={'name':['rama','don','hari'],
     'age':[45,44,25],
     'add':['ktm','bkt','lalitpur']}
df=pd.DataFrame(data)
print(df)
df.to_csv('new_data.csv')  #for export in excel this line
# Out:
#    name  age       add
# 0  rama   45       ktm
# 1   don   44       bkt
# 2  hari   25  lalitpur

# %%
import pandas as pd
df1=pd.DataFrame({'name':['rama','don','hari'],
     'age':[45,44,25],
     'add':['ktm','bkt','lalitpur']})
df2=pd.DataFrame({'name':['raju','ram','gori'],
     'age':[45,44,25],
     'add':['ktm','bkt','lalitpur']})
df3=pd.DataFrame({'name':['void','anitmage','volaa'],
     'age':[45,44,25],
     'add':['ktm','bkt','lalitpur']})
df=pd.concat([df1,df2,df3])
df
# Out:
#        name  age       add
# 0      rama   45       ktm
# 1       don   44       bkt
# 2      hari   25  lalitpur
# 0      raju   45       ktm
# 1       ram   44       bkt
# 2      gori   25  lalitpur
# 0      void   45       ktm
# 1  anitmage   44       bkt
# 2     volaa   25  lalitpur

# %%
data={'name':['rama','don','hari'],
     'age':[45,44,25],
     'add':['ktm','bkt','lalitpur']}
df=pd.DataFrame(data)
df.to_json('new_datas.json')
df
# Out:
#    name  age       add
# 0  rama   45       ktm
# 1   don   44       bkt
# 2  hari   25  lalitpur

# %%
# !pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xlrd in c:\programdata\anaconda3\lib\site-packages (2.0.1)

# %%
# # !pip install xlrd

# import pandas as pd
# df=pd.read_excel('')
# df
